# %%
import pandas as pd

# %%
Health_expenditure = pd.read_csv('Health expenditure and financing.csv', sep = ',')
Health_expenditure
# Out:
#            HF                  Financing scheme     HC  \
# 0       HFTOT             All financing schemes  HCTOT
# 1       HFTOT             All financing schemes  HCTOT
# 2       HFTOT             All financing schemes  HCTOT
# 3       HFTOT             All financing schemes  HCTOT
# 4       HFTOT             All financing schemes  HCTOT
# ...       ...                               ...    ...
# 210685    HF3  Household out-of-pocket payments    HC0
# 210686    HF3  Household out-of-pocket payments    HC0
# 210687    HF3  Household out-of-pocket payments    HC0
# 210688    HF3  Household out-of-pocket payments    HC0
# 210689    HF3  Household out-of-pocket payments    HC0
#
#                                              Function     HP       Provider  \
# 0       Current expenditure on health (all functions)  HPTOT  All providers
# 1       Current expenditure on health (all functions)  HPTOT  All providers
# ...

# %%
health_employment = pd.read_csv('Total health and social employment.csv', sep = ',')
health_employment
# Out:
#            VAR                            Variable      UNIT  \
# 0     GEHETHSM  Total health and social employment  PERSMYNB
# 1     GEHETHSM  Total health and social employment  PERSMYNB
# 2     GEHETHSM  Total health and social employment  PERSMYNB
# 3     GEHETHSM  Total health and social employment  PERSMYNB
# 4     GEHETHSM  Total health and social employment  PERSMYNB
# ...        ...                                 ...       ...
# 1228  GEHETHSM  Total health and social employment  PERSMYNB
# 1229  GEHETHSM  Total health and social employment  PERSMYNB
# 1230  GEHETHSM  Total health and social employment  PERSMYNB
# 1231  GEHETHSM  Total health and social employment  PERSMYNB
# 1232  GEHETHSM  Total health and social employment  PERSMYNB
#
#                               Measure  COU    Country   YEA  Year       Value  \
# 0     Number of persons (head counts)  AUS  Australia  2010  2010  1266930.91
# ...

# %%
hospitals = pd.read_csv('Hospitals.csv', sep = ',')
hospitals
# Out:
#            VAR           Variable      UNIT                 Measure  COU  \
# 0     HOSPTHOS          Hospitals  NOMBRENB                  Number  AUS
# 1     HOSPTHOS          Hospitals  NOMBRENB                  Number  AUS
# 2     HOSPTHOS          Hospitals  NOMBRENB                  Number  AUS
# 3     HOSPTHOS          Hospitals  NOMBRENB                  Number  AUS
# 4     HOSPTHOS          Hospitals  NOMBRENB                  Number  AUS
# ...        ...                ...       ...                     ...  ...
# 3341  HOSPGHOS  General hospitals  NBMILPNB  Per million population  COL
# 3342  HOSPGHOS  General hospitals  NBMILPNB  Per million population  COL
# 3343  HOSPGHOS  General hospitals  NBMILPNB  Per million population  COL
# 3344  HOSPGHOS  General hospitals  NBMILPNB  Per million population  COL
# 3345  HOSPGHOS  General hospitals  NBMILPNB  Per million population  COL
#
#         Country   YEA  Year    Value Flag Codes Flags
# ...

# %%
hospitalbeds_function = pd.read_csv('Hospital beds by function of health care.csv', sep = ',')
hospitalbeds_function
# Out:
#            VAR                     Variable      UNIT  \
# 0     HOPBLTPH  Long-term somatic care beds  LTCOVRNB
# 1     HOPBLTPH  Long-term somatic care beds  LTCOVRNB
# 2     HOPBLTPH  Long-term somatic care beds  LTCOVRNB
# 3     HOPBLTPH  Long-term somatic care beds  LTCOVRNB
# 4     HOPBLTPH  Long-term somatic care beds  LTCOVRNB
# ...        ...                          ...       ...
# 7944  HOPBLICS   Curative (acute) care beds  NOMBRENB
# 7945  HOPBLICS   Curative (acute) care beds  NOMBRENB
# 7946  HOPBLICS   Curative (acute) care beds  NOMBRENB
# 7947  HOPBLICS   Curative (acute) care beds  NOMBRENB
# 7948  HOPBLICS   Curative (acute) care beds  NOMBRENB
#
#                                               Measure  COU   Country   YEA  \
# 0     Per 1 000 population aged 65 years old and over  FIN   Finland  2010
# 1     Per 1 000 population aged 65 years old and over  FIN   Finland  2011
# 2     Per 1 000 population aged 65 years old and over  FIN   Finland  2012
# ...

# %%
covid_cases = pd.read_csv('time_series_covid19_confirmed_global.csv', sep = ',')
covid_cases
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# ...

# %%
covid_death_cases = pd.read_csv('time_series_covid19_deaths_global.csv', sep = ',')
covid_death_cases
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# ...

# %%
healthcare_dataset = [Health_expenditure, health_employment, hospitals, hospitalbeds_function, covid_cases, covid_death_cases]
healthcare_dataset = pd.concat(healthcare_dataset)
healthcare_dataset
# Out:
#         HF       Financing scheme     HC  \
# 0    HFTOT  All financing schemes  HCTOT
# 1    HFTOT  All financing schemes  HCTOT
# 2    HFTOT  All financing schemes  HCTOT
# 3    HFTOT  All financing schemes  HCTOT
# 4    HFTOT  All financing schemes  HCTOT
# ..     ...                    ...    ...
# 284    NaN                    NaN    NaN
# 285    NaN                    NaN    NaN
# 286    NaN                    NaN    NaN
# 287    NaN                    NaN    NaN
# 288    NaN                    NaN    NaN
#
#                                           Function     HP       Provider  \
# 0    Current expenditure on health (all functions)  HPTOT  All providers
# 1    Current expenditure on health (all functions)  HPTOT  All providers
# 2    Current expenditure on health (all functions)  HPTOT  All providers
# 3    Current expenditure on health (all functions)  HPTOT  All providers
# 4    Current expenditure on health (all functions)  HPTOT  All providers
# ...
